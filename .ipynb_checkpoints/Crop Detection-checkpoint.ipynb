# %% [markdown]
# ## Clustrering Valadation on KMeans and DBSCAN Algorithm using Soli Fertility Dataset

# %% [markdown]
# ### Analysis using Kmeans Clustering Algorithm

# %%
echo "Clustering"
# Out:
# "Clustering"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('soildataset.csv')
Y = dataset.iloc[:,1:7].replace({'Low': 1, 'Medium': 2, 'High': 3}).values
#Y = dataset.iloc[:, 4:7].replace({'Low': 1, 'Medium': 2, 'High': 3}).values
#print(X)
data = pd.read_csv("Crop_recommendation.csv")
X = data.iloc[:, 4:7].values

# %%
dataset.head()
print(data.head())
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 10):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 10), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ###  From the above elbow we can clearly depict that the optimal no of clusters are between 5 to 10
# ### So finding the silhoutte coefficient for the range 5 to 10 will give us the correct value of Optimum Clusters.

# %% [markdown]
# #### Silhouette Score = (b-a)/max(a,b)
# #### a= average intra-cluster distance i.e the average distance between each point within a cluster.
# ####  b= average inter-cluster distance i.e the average distance between all clusters.

# %% [markdown]
# #### Here we are going to evaluate silhoutte score using silhoutte_score attribute of metric module of sklearn library

# %%
from sklearn import metrics

for i in range(2, 6):
    test_kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    test_kmeans.fit(X)
    test_labels = test_kmeans.predict(X)
    # print()
    print("Silhoutte_score for n_cluster = " + str(i) + " is : " + str(metrics.silhouette_score(X,test_labels)))
# Out:
# Silhoutte_score for n_cluster = 2 is : 0.5630058176363574
# Silhoutte_score for n_cluster = 3 is : 0.4414887925395374
# Silhoutte_score for n_cluster = 4 is : 0.506353780754012
# Silhoutte_score for n_cluster = 5 is : 0.5043893899714336

# %%
kmeans = KMeans(n_clusters=2, init='k-means++', random_state=42)
kmeans.fit(X)
labels = kmeans.predict(X)
print(labels)
labels
#print(X)
# Out:
# [0 0 0 ... 0 1 0]
# array([0, 0, 0, ..., 0, 1, 0])

# %%
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[labels==0, 0], X[labels==0, 1], X[labels==0, 2], s=100, c='red', label='Cluster 1')
ax.scatter(X[labels==1, 0], X[labels==1, 1], X[labels==1, 2], s=100, c='orange', label='Cluster 2')
# ax.scatter(X[labels==2, 0], X[labels==2, 1], X[labels==2, 2], s=100, c='yellow', label='Cluster 3')
# ax.scatter(X[labels==3, 0], X[labels==3, 1], X[labels==3, 2], s=100, c='brown', label='Cluster 4')
# ax.scatter(X[labels==4, 0], X[labels==4, 1], X[labels==4, 2], s=100, c='blue', label='Cluster 5')
# ax.scatter(X[labels==5, 0], X[labels==5, 1], X[labels==5, 2], s=100, c='indigo', label='Cluster 6')
# ax.scatter(X[labels==6, 0], X[labels==6, 1], X[labels==6, 2], s=100, c='darkgreen', label='Cluster 7')
# ax.scatter(X[labels==7, 0], X[labels==7, 1], X[labels==7, 2], s=100, c='#ff00ff', label='Cluster 8')

ax.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], kmeans.cluster_centers_[:, 2], s=100, c='black', label='Centroids')
ax.set_title('Clusters of Soil Nutrients')
ax.set_xlabel('Nitrogen')
ax.set_ylabel('Phosphorous')
ax.set_zlabel('Potassium')
#legend.loc()
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# ###  Analysis Using DBSCAN Algorithm

# %%
print()
